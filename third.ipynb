# %%
def my_add(a, b):
    return a+b

def my_sub(a, b):
    return a-b


print(my_add(3, 4))
print(my_sub(10, 5))
# Out:
# 7
# 5

# %%
import mypackage.text_tool

mypackage.text_tool.fjf('박태수')
# Out:
# '박태수'

# %%
import mypackage.calc_tool

mypackage.calc_tool.mul(9,2)
# Out:
# 18

# %%
from mypackage import text_tool, calc_tool

print(text_tool.greet('진정국'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 from mypackage import text_tool, calc_tool
#       2
# ----> 3 print(text_tool.greet('진정국'))
#
# AttributeError: module 'mypackage.text_tool' has no attribute 'greet'
